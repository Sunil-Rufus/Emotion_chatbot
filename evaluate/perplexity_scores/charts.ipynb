# %%
import numpy as np
import matplotlib.pyplot as plt

mistral_base_boh_out = np.load("esconv/mistral/mistral_base_out_boh.npy", allow_pickle=True)
llama_base_boh = np.load("esconv/llama/mistral_base_boh.npy", allow_pickle=True)
mistral_base_out = np.load("esconv/mistral/mistral_base_out.npy", allow_pickle=True)
mistral_base = np.load("esconv/mistral/mistral_base.npy", allow_pickle=True)
mistral_tuned_boh_out = np.load("esconv/mistral/mistral_tuned_out_boh.npy", allow_pickle=True)
mistral_tuned_boh = np.load("esconv/mistral/mistral_tuned_boh.npy", allow_pickle=True)
mistral_tuned_out = np.load("esconv/mistral/mistral_tuned_out.npy", allow_pickle=True)
mistral_tuned = np.load("esconv/mistral/mistral_tuned.npy", allow_pickle=True)

# %%
print(mistral_tuned_boh_out)
print(mistral_tuned_out)
# Out:
# [[  9  51 127 141 221 297 364 402 442 499]
#  [ 13  59 111 181 246 309 385 443 505 566]
#  [  9  33  50  76 114 140 175 217 252 294]
#  [ 10  43  76 144 202 259 337 399 470 537]]
# [[   9  102  237  327  511  675  800  924 1025 1163]
#  [  16  158  314  477  630  784  957 1109 1262 1413]
#  [   9   49   99  153  242  321  396  494  578  656]
#  [  10   30   64  122  194  264  361  433  542  628]]

# %%
mistral_base_boh_out = np.mean(mistral_base_boh_out, axis=0)
mistral_base_boh = np.mean(mistral_base_boh, axis=0)
mistral_base_out = np.mean(mistral_base_out, axis=0)
mistral_base = np.mean(mistral_base, axis=0)
mistral_tuned_boh_out = np.mean(mistral_tuned_boh_out, axis=0)
mistral_tuned_boh = np.mean(mistral_tuned_boh, axis=0)
mistral_tuned_out = np.mean(mistral_tuned_out, axis=0)
mistral_tuned = np.mean(mistral_tuned, axis=0)

# %%
print(mistral_tuned_boh_out)
# Out:
# [223.97795  107.27228   93.842384  89.68566   86.54853   60.938362
#   48.792908  45.678288  39.462288  38.796173  33.548183  32.99126
#   32.360638  30.472614  28.778976  25.69719   25.69719   23.340721
#   22.503195  20.833439]

# %%
import matplotlib.pyplot as plt

plt.plot(mistral_base, label='mistral_base')
plt.plot(mistral_tuned, label='mistral_tuned')
plt.plot(mistral_base_boh, label='mistral_base_no_sw')
plt.plot(mistral_tuned_boh, label='mistral_tuned_no_sw')
plt.xlabel('Number of dialogues')
plt.ylabel('Perplexity Value')
plt.yscale('log')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(mistral_base_out, label='mistral_base')
plt.plot(mistral_tuned_out, label='mistral_tuned')
plt.plot(mistral_base_boh_out, label='mistral_base_no_sw')
plt.plot(mistral_tuned_boh_out, label='mistral_tuned_no_sw')
plt.xlabel('Number of dialogues')
plt.ylabel('Content length')
#plt.yscale('log')
plt.legend()
plt.show()

# %%
import numpy as np
mistral_tuned_boh = np.load("mistral/mistral_tuned_boh_out.npy", allow_pickle=True)
mistral_tuned = np.load("mistral/mistral_tuned_out.npy", allow_pickle=True)
mistral_base_boh = np.load("mistral/mistral_base_boh_out.npy", allow_pickle=True)
mistral_base = np.load("mistral/mistral_base_out.npy", allow_pickle=True)

# %%
print(mistral_base)
print(mistral_tuned)
# Out:
# [[  16  106  288  461  638  801  974 1089]
#  [  26  199  384  555  712  866 1022 1191]
#  [  25  205  365  523  682  840  993 1105]
#  [  26  196  360  517  687  849 1010 1168]
#  [  27  135  307  465  619  779  944 1106]]
# [[ 16  73 183 288 409 519 616 685]
#  [ 26  89 183 273 360 438 531 612]
#  [ 25  94 172 256 352 435 534 628]
#  [ 26  85 146 207 292 382 462 528]
#  [ 27  88 171 251 338 435 548 635]]

# %%
mistral_base = np.mean(mistral_base, axis=0)
mistral_tuned = np.mean(mistral_tuned, axis=0)
mistral_tuned_boh = np.mean(mistral_tuned_boh, axis=0)
mistral_base_boh = np.mean(mistral_base_boh, axis=0)

# %%
import matplotlib.pyplot as plt

plt.plot(mistral_base, label='mistral_base')
plt.plot(mistral_tuned, label='mistral_tuned')
plt.plot(mistral_base_boh, label='mistral_base_no_sw')
plt.plot(mistral_tuned_boh, label='mistral_tuned_no_sw')
plt.xlabel('Number of dialogues')
plt.ylabel('Perplexity Value')
plt.yscale('log')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(mistral_base, label='mistral_base')
plt.plot(mistral_tuned, label='mistral_tuned')
plt.plot(mistral_base_boh, label='mistral_base_no_sw')
plt.plot(mistral_tuned_boh, label='mistral_tuned_no_sw')
plt.xlabel('Number of dialogues')
plt.ylabel('Content length')
#plt.yscale('log')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.bar(x='Name', height='Age', data=df, color='blue')
plt.xlabel('Name')
plt.ylabel('Age')
plt.title('Bar Chart')
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the variables for the x-axis and y-axis
x = ['llama_base', 'llama_base_wo_sw', 'llama_tuned', 'llama_tuned_wo_sw']
y = [24, 35, 47, 114]

# Create the bar plot
plt.bar(x, y, color=['blue', 'green', 'orange', 'red' ])

# Add labels and title
plt.xlabel('Model')
plt.ylabel('Number of turns')
plt.title('Llama turns for different configurations')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=90)

# Display the plot
plt.show()
